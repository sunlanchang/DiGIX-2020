# %%
## w2v 特征 不用跑完，抽几个跑
#!/usr/bin/env python 
# encoding: utf-8 

"""
@version: v1.0
@author: zhenglinghan
@contact: 422807471@qq.com
@software: PyCharm
@file: test_w2v_feature.py
@time: 2020/9/12 20:33
"""

import pandas as pd
import numpy as np
import os
import gc
import datetime as dt
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('precision', 5)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('max_colwidth', 200)
pd.set_option('display.width', 5000)

from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora, models, similarities
from gensim.models.doc2vec import TaggedDocument

import gc
from base import Cache
from tqdm import tqdm
import multiprocessing


def reduce_mem(df, use_float16=False):
    start_mem = df.memory_usage().sum() / 1024 ** 2
    tm_cols = df.select_dtypes('datetime').columns
    colsuse = [i for i in df.columns if i != 'label']
    for col in colsuse:
        if col in tm_cols:
            continue
        col_type = df[col].dtypes
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(
                        np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(
                        np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(
                        np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(
                        np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if use_float16 and c_min > np.finfo(
                        np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(
                        np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('{:.2f} Mb, {:.2f} Mb ({:.2f} %)'.format(
        start_mem, end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df


'''
# 封装类
class text_emb_tool:
    def __init__(self, seq_len):
        self.seq_len = seq_len
        self.temp_list = []
        self.temp_index = []
        self.dictionary = []
        self.corpus = []
        self.corpus_tfidf = []
        
    def func_pad(self, arr):
        arr = arr.T
        arr = pad_sequences(arr, maxlen=self.seq_len, padding='pre',
                            truncating='pre', dtype='float32', value=0.0)
        arr = arr.T
        return arr

    def get_tmp_list(self, col):
        arr = id_list_dict[col+'_list']['id_list'].copy()
        arr = arr.astype(str)
        self.temp_list = []
        for i in tqdm(range(len(arr))):
            tpi = list(filter(lambda number: number != '0', arr[i]))
            self.temp_list.append(tpi)
        # get tfidf embedding
        print('dictionary start!')
        self.dictionary = corpora.Dictionary(self.temp_list, prune_at=None)
        self.corpus = [self.dictionary.doc2bow(
            text) for text in self.temp_list]
        self.corpus_tfidf = models.TfidfModel(self.corpus)[self.corpus]
        print('dictionary finish!')
        # 序列转词表索引
        print('dictionary index start!')
        self.temp_index = []
        for si in tqdm(self.temp_list):
            sentencei = [self.dictionary.token2id[i] for i in si]
            self.temp_index.append(sentencei)
        print('dictionary index finish!')

    def get_embeddings(self):
        tfidf_dict = {}
        array_tfidf = []
        for index, sentencei in enumerate(self.temp_list):
            if index % 100000 == 0:
                print(index)
            tfidf_dict = dict(self.corpus_tfidf[index])  # 词表索引：tfidf
            # sentencei-># 词表索引
            sentencei_index = self.temp_index[index]
            # tfidf
            tfidfs = list(map(lambda x: tfidf_dict[x], sentencei_index))
            array_tfidf.append(tfidfs)
        tfidfs = pad_sequences(array_tfidf, maxlen=self.seq_len,
                               padding='pre', truncating='pre', dtype='float32', value=0.0)
        array_tfidf = np.array(tfidfs)  # id * seqlen
        array_tfidf = array_tfidf.reshape(
            len(self.temp_list), -1, 1)  # id seqlen 1
        print('return tfidf matrix shape:', array_tfidf.shape)
        return array_tfidf
# Out:
# [2020-09-13 17:09:13] - __init__.py[line:126] - INFO: Successfully Reload: /home/tione/notebook/huawei/cached_data/CACHE_data_0912.pkl
# [2020-09-13 17:11:46] - word2vec.py[line:1399] - INFO: collecting all words and their counts
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #10000, processed 202236 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #20000, processed 405861 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #30000, processed 614005 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #40000, processed 817478 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #50000, processed 1015563 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #60000, processed 1218117 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #70000, processed 1417420 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #80000, processed 1623254 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #90000, processed 1818415 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #100000, processed 2015198 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #110000, processed 2214828 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #120000, processed 2418384 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #130000, processed 2619769 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #140000, processed 2823782 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #150000, processed 3021113 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #160000, processed 3220545 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #170000, processed 3424875 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #180000, processed 3624353 words, keeping 25 word types
# [2020-09-13 17:11:46] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #190000, processed 3830584 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #200000, processed 4033344 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #210000, processed 4236703 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #220000, processed 4433979 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #230000, processed 4639009 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #240000, processed 4842893 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #250000, processed 5039269 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #260000, processed 5237142 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #270000, processed 5439431 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #280000, processed 5636674 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #290000, processed 5838760 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #300000, processed 6030886 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #310000, processed 6235571 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #320000, processed 6438949 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #330000, processed 6634462 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #340000, processed 6836631 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #350000, processed 7041943 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #360000, processed 7245311 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #370000, processed 7453177 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #380000, processed 7652605 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #390000, processed 7851348 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #400000, processed 8055791 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #410000, processed 8255296 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #420000, processed 8455555 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #430000, processed 8651427 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #440000, processed 8858140 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #450000, processed 9064744 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #460000, processed 9266210 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #470000, processed 9459721 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #480000, processed 9661323 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #490000, processed 9859239 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #500000, processed 10058265 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #510000, processed 10261486 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #520000, processed 10464011 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #530000, processed 10669115 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #540000, processed 10865843 words, keeping 25 word types
# [2020-09-13 17:11:47] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #550000, processed 11063429 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #560000, processed 11264543 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #570000, processed 11466733 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #580000, processed 11671632 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #590000, processed 11876808 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #600000, processed 12079701 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #610000, processed 12273740 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #620000, processed 12474735 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #630000, processed 12677510 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #640000, processed 12884675 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #650000, processed 13084805 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #660000, processed 13287366 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #670000, processed 13490919 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #680000, processed 13693660 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #690000, processed 13893993 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #700000, processed 14097768 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #710000, processed 14296063 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #720000, processed 14498919 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #730000, processed 14700498 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #740000, processed 14902664 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #750000, processed 15100254 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #760000, processed 15304432 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #770000, processed 15500243 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #780000, processed 15704260 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #790000, processed 15905210 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #800000, processed 16106607 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #810000, processed 16308955 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #820000, processed 16512522 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #830000, processed 16713622 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #840000, processed 16908871 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #850000, processed 17110125 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #860000, processed 17311885 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #870000, processed 17510894 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #880000, processed 17715003 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #890000, processed 17910601 words, keeping 25 word types
# [2020-09-13 17:11:48] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #900000, processed 18109969 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #910000, processed 18310022 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #920000, processed 18506894 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #930000, processed 18710211 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #940000, processed 18910632 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #950000, processed 19112582 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #960000, processed 19312622 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #970000, processed 19512951 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #980000, processed 19714275 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #990000, processed 19908698 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1000000, processed 20108426 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1010000, processed 20310240 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1020000, processed 20505972 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1030000, processed 20713335 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1040000, processed 20907830 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1050000, processed 21109618 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1060000, processed 21314646 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1070000, processed 21511727 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1080000, processed 21707321 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1090000, processed 21910453 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1100000, processed 22112677 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1110000, processed 22316188 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1120000, processed 22514992 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1130000, processed 22711677 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1140000, processed 22909589 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1150000, processed 23106069 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1160000, processed 23308242 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1170000, processed 23506183 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1180000, processed 23706126 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1190000, processed 23906412 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1200000, processed 24107207 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1210000, processed 24312797 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1220000, processed 24517445 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1230000, processed 24715395 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1240000, processed 24909094 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1250000, processed 25113032 words, keeping 25 word types
# [2020-09-13 17:11:49] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1260000, processed 25317546 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1270000, processed 25519639 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1280000, processed 25724030 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1290000, processed 25931246 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1300000, processed 26121496 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1310000, processed 26322167 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1320000, processed 26522340 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1330000, processed 26720402 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1340000, processed 26918294 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1350000, processed 27125604 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1360000, processed 27323847 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1370000, processed 27525709 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1380000, processed 27726650 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1390000, processed 27931586 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1400000, processed 28129351 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1410000, processed 28329820 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1420000, processed 28528626 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1430000, processed 28729732 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1440000, processed 28929983 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1450000, processed 29134105 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1460000, processed 29330737 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1470000, processed 29535459 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1480000, processed 29737184 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1490000, processed 29940010 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1500000, processed 30135892 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1510000, processed 30330607 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1520000, processed 30529248 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1530000, processed 30727775 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1540000, processed 30935705 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1550000, processed 31133196 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1560000, processed 31333391 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1570000, processed 31534566 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1580000, processed 31738231 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1590000, processed 31936452 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1600000, processed 32141599 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1610000, processed 32344782 words, keeping 25 word types
# [2020-09-13 17:11:50] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1620000, processed 32543547 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1630000, processed 32744414 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1640000, processed 32944742 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1650000, processed 33153892 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1660000, processed 33355258 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1670000, processed 33560457 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1680000, processed 33761147 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1690000, processed 33957945 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1700000, processed 34150159 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1710000, processed 34349071 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1720000, processed 34549334 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1730000, processed 34753453 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1740000, processed 34953531 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1750000, processed 35149162 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1760000, processed 35346921 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1770000, processed 35544342 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1780000, processed 35745543 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1790000, processed 35943174 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1800000, processed 36140799 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1810000, processed 36343036 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1820000, processed 36547707 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1830000, processed 36746331 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1840000, processed 36951464 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1850000, processed 37151574 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1860000, processed 37355573 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1870000, processed 37559474 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1880000, processed 37761324 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1890000, processed 37958636 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1900000, processed 38160573 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1910000, processed 38354096 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1920000, processed 38550043 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1930000, processed 38752772 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1940000, processed 38955019 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1950000, processed 39157877 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1960000, processed 39359427 words, keeping 25 word types
# [2020-09-13 17:11:51] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1970000, processed 39555993 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1980000, processed 39760305 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #1990000, processed 39961215 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2000000, processed 40157345 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2010000, processed 40355114 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2020000, processed 40557004 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2030000, processed 40760387 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2040000, processed 40957457 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2050000, processed 41156268 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2060000, processed 41360772 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2070000, processed 41559387 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2080000, processed 41760702 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2090000, processed 41954271 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2100000, processed 42152692 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2110000, processed 42356985 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2120000, processed 42556624 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2130000, processed 42765978 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2140000, processed 42965859 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2150000, processed 43167488 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2160000, processed 43367399 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2170000, processed 43568203 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2180000, processed 43769007 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2190000, processed 43971269 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2200000, processed 44174360 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2210000, processed 44370986 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2220000, processed 44571610 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2230000, processed 44770887 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2240000, processed 44970714 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2250000, processed 45170390 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2260000, processed 45374562 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2270000, processed 45572241 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2280000, processed 45775481 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2290000, processed 45969858 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2300000, processed 46172876 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2310000, processed 46377758 words, keeping 25 word types
# [2020-09-13 17:11:52] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2320000, processed 46576695 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2330000, processed 46773881 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2340000, processed 46975365 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2350000, processed 47177347 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2360000, processed 47378483 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2370000, processed 47572926 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2380000, processed 47769288 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2390000, processed 47972616 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2400000, processed 48176713 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2410000, processed 48374481 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2420000, processed 48573906 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2430000, processed 48771303 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2440000, processed 48975791 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2450000, processed 49179215 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2460000, processed 49382201 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2470000, processed 49580915 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2480000, processed 49783429 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2490000, processed 49984053 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2500000, processed 50184589 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2510000, processed 50384709 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2520000, processed 50588083 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2530000, processed 50785917 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2540000, processed 50993592 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2550000, processed 51195626 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2560000, processed 51398503 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2570000, processed 51601155 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2580000, processed 51807756 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2590000, processed 52010649 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2600000, processed 52213802 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2610000, processed 52411780 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2620000, processed 52612054 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2630000, processed 52816640 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2640000, processed 53012695 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2650000, processed 53211498 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2660000, processed 53417031 words, keeping 25 word types
# [2020-09-13 17:11:53] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2670000, processed 53617362 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2680000, processed 53817503 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2690000, processed 54021867 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2700000, processed 54214979 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2710000, processed 54418784 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2720000, processed 54615928 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2730000, processed 54814462 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2740000, processed 55014297 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2750000, processed 55217069 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2760000, processed 55416369 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2770000, processed 55616003 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2780000, processed 55811747 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2790000, processed 56014330 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2800000, processed 56211279 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2810000, processed 56413341 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2820000, processed 56619051 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2830000, processed 56820574 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2840000, processed 57020000 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2850000, processed 57220890 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2860000, processed 57421605 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2870000, processed 57622384 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2880000, processed 57827301 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2890000, processed 58032855 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2900000, processed 58236284 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2910000, processed 58434514 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2920000, processed 58629623 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2930000, processed 58829320 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2940000, processed 59025502 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2950000, processed 59227298 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2960000, processed 59427664 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2970000, processed 59628046 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2980000, processed 59828638 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #2990000, processed 60031581 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3000000, processed 60232241 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3010000, processed 60432541 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3020000, processed 60635357 words, keeping 25 word types
# [2020-09-13 17:11:54] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3030000, processed 60831146 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3040000, processed 61034672 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3050000, processed 61239737 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3060000, processed 61435791 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3070000, processed 61633553 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3080000, processed 61837135 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3090000, processed 62032461 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3100000, processed 62227893 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3110000, processed 62433192 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3120000, processed 62633166 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3130000, processed 62834095 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3140000, processed 63036303 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3150000, processed 63239442 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3160000, processed 63443110 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3170000, processed 63646565 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3180000, processed 63843012 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3190000, processed 64042903 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3200000, processed 64241567 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3210000, processed 64439972 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3220000, processed 64638866 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3230000, processed 64839509 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3240000, processed 65043389 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3250000, processed 65247413 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3260000, processed 65449632 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3270000, processed 65651887 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3280000, processed 65858402 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3290000, processed 66062802 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3300000, processed 66268401 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3310000, processed 66470097 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3320000, processed 66665626 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3330000, processed 66871656 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3340000, processed 67079164 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3350000, processed 67284088 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3360000, processed 67486109 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3370000, processed 67686424 words, keeping 25 word types
# [2020-09-13 17:11:55] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3380000, processed 67887334 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3390000, processed 68091227 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3400000, processed 68295180 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3410000, processed 68488992 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3420000, processed 68690277 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3430000, processed 68892329 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3440000, processed 69093125 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3450000, processed 69293605 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3460000, processed 69497202 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3470000, processed 69697597 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3480000, processed 69897190 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3490000, processed 70098425 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3500000, processed 70297980 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3510000, processed 70496174 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3520000, processed 70698528 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3530000, processed 70906459 words, keeping 25 word types
# [2020-09-13 17:11:56] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #3540000, processed 71110564 words, keeping 25 word types
# ...
# [2020-09-13 21:08:28] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 36.57% examples, 214487 words/s, in_qsize 94, out_qsize 5
# [2020-09-13 21:08:29] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 37.46% examples, 214431 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:30] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 38.39% examples, 214360 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:31] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 39.32% examples, 214310 words/s, in_qsize 96, out_qsize 3
# [2020-09-13 21:08:32] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 40.21% examples, 214349 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:33] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 41.16% examples, 214440 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:34] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 42.08% examples, 214330 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:35] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 42.99% examples, 214340 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:36] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 43.90% examples, 214282 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:37] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 44.83% examples, 214376 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:38] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 45.74% examples, 214420 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:39] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 46.64% examples, 214331 words/s, in_qsize 100, out_qsize 1
# [2020-09-13 21:08:40] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 47.55% examples, 214370 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:41] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 48.46% examples, 214369 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:42] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 49.43% examples, 214385 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:43] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 50.32% examples, 214349 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:44] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 51.26% examples, 214365 words/s, in_qsize 95, out_qsize 4
# [2020-09-13 21:08:45] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 52.19% examples, 214292 words/s, in_qsize 96, out_qsize 3
# [2020-09-13 21:08:46] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 53.10% examples, 214421 words/s, in_qsize 100, out_qsize 1
# [2020-09-13 21:08:47] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 54.01% examples, 214483 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:48] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 54.90% examples, 214500 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:49] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 55.79% examples, 214508 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:50] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 56.72% examples, 214512 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:51] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 57.61% examples, 214493 words/s, in_qsize 93, out_qsize 8
# [2020-09-13 21:08:52] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 58.52% examples, 214560 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:53] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 59.41% examples, 214619 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:54] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 60.34% examples, 214621 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:08:55] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 61.24% examples, 214574 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:56] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 62.19% examples, 214590 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:08:57] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 63.09% examples, 214670 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:08:58] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 64.01% examples, 214740 words/s, in_qsize 97, out_qsize 2
# [2020-09-13 21:08:59] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 64.95% examples, 214716 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:00] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 65.85% examples, 214733 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:01] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 66.70% examples, 214517 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:02] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 67.60% examples, 214525 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:03] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 68.49% examples, 214512 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:04] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 69.44% examples, 214518 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:05] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 70.36% examples, 214499 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:06] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 71.25% examples, 214524 words/s, in_qsize 94, out_qsize 5
# [2020-09-13 21:09:07] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 72.17% examples, 214542 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:08] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 73.08% examples, 214501 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:09] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 73.99% examples, 214425 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:10] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 74.92% examples, 214382 words/s, in_qsize 100, out_qsize 1
# [2020-09-13 21:09:11] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 75.80% examples, 214273 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:12] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 76.68% examples, 214062 words/s, in_qsize 83, out_qsize 11
# [2020-09-13 21:09:13] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 77.62% examples, 214106 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:14] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 78.57% examples, 214058 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:15] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 79.49% examples, 214091 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:16] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 80.35% examples, 214119 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:17] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 81.27% examples, 214082 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:18] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 82.15% examples, 214073 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:19] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 83.01% examples, 214059 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:20] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 83.88% examples, 214040 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:21] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 84.79% examples, 214075 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:22] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 85.72% examples, 214106 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:23] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 86.61% examples, 214073 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:24] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 87.51% examples, 214049 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:25] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 88.43% examples, 213984 words/s, in_qsize 100, out_qsize 1
# [2020-09-13 21:09:26] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 89.34% examples, 214020 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:27] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 90.21% examples, 214009 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:28] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 91.12% examples, 213982 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:29] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 92.06% examples, 213978 words/s, in_qsize 98, out_qsize 1
# [2020-09-13 21:09:30] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 92.99% examples, 214002 words/s, in_qsize 96, out_qsize 3
# [2020-09-13 21:09:31] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 93.92% examples, 213998 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:32] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 94.83% examples, 213990 words/s, in_qsize 100, out_qsize 3
# [2020-09-13 21:09:33] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 95.73% examples, 213969 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:34] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 96.63% examples, 213984 words/s, in_qsize 95, out_qsize 4
# [2020-09-13 21:09:35] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 97.51% examples, 213972 words/s, in_qsize 100, out_qsize 0
# [2020-09-13 21:09:36] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 98.42% examples, 213982 words/s, in_qsize 99, out_qsize 0
# [2020-09-13 21:09:37] - base_any2vec.py[line:1291] - INFO: EPOCH 5 - PROGRESS: at 99.36% examples, 213962 words/s, in_qsize 97, out_qsize 2
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 49 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 48 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 47 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 46 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 45 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 44 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 43 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 42 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 41 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 40 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 39 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 38 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 37 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 36 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 35 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 34 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 33 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 32 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 31 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 30 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 29 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 28 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 27 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 26 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 25 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 24 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 23 more threads
# [2020-09-13 21:09:37] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 22 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 21 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 20 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 19 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 18 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 17 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 16 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 15 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 14 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 13 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 12 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 11 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 10 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 9 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 8 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 7 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 6 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 5 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 4 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 3 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 2 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 1 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 0 more threads
# [2020-09-13 21:09:38] - base_any2vec.py[line:1332] - INFO: EPOCH - 5 : training on 491030428 raw words (23554475 effective words) took 110.0s, 214174 effective words/s
# [2020-09-13 21:09:38] - base_any2vec.py[line:1368] - INFO: training on a 2455152140 raw words (117797962 effective words) took 550.5s, 213997 effective words/s

# %%
# 每个列提取哪些emb
cols_to_emb = ['creative_id', 'ad_id', 'advertiser_id', 'product_id','product_category', 'industry','time']
# 开跑
import gc
# id_list_dict = {}
# for key,value in id_list_dict0.items():
#     id_list_dict[key]={}
#     id_list_dict[key]['id_list']=value['id_list'][:500,:]
for var in cols_to_emb:
    res_dict = {}
    tet = text_emb_tool(seq_len = 120)
    tet.get_tmp_list(var)# 字典 索引
    emb_matrix = tet.get_embeddings()
    res_dict['word_emb_dict'] = emb_matrix
    print(res_dict)
    Cache.cache_data(res_dict,nm_marker=f'EMB_DICT_TEXTEMB_{var}_tfidf')
    print(f'EMB_DICT_TEXTEMB_{var}'+' finished!')
    del tet
    gc.collect()
print('text_embedding_finished!')
'''


def get_embedding_pro(df_raw, sentence_id, word_id, emb_size=128, window=10,
                      dropna=False, n_jobs=4, method='skipgram',
                      hs=0, negative=10, epoch=10, return_model=False,
                      embedding_type='fasttext', slide_window=1):
    """
    Now, set min_count=1 to avoid OOV...
    How to deal with oov in a more appropriate way...
    Paramter:
    ----------
    df_raw: DataFrame contains columns named sentence_id and word_id
    sentence_id: like user ID, will be coerced into str
    word_id: like item ID, will be coerced into str
    emb_size: default 8
    dropna: default False, nans will be filled with 'NULL_zhangqibot'. if True, nans will all be dropped.
    n_jobs: 4 cpus to use as default
    method: 'sg'/'skipgram' or 'cbow'
        sg : {0, 1}, optional
            Training algorithm: 1 for skip-gram; otherwise CBOW.
    hs : {0, 1}, optional
        If 1, hierarchical softmax will be used for model training.
        If 0, and `negative` is non-zero, negative sampling will be used.
    negative : int, optional
        If > 0, negative sampling will be used, the int for negative specifies how many "noise words"
        should be drawn (usually between 5-20).
        If set to 0, no negative sampling is used.
    epoch: iter : int, optional,default 10
        Number of iterations (epochs) over the corpus.
    return_model: default True
    embedding_type: fasttext word2vec
    Return:
    ----------
    Example:
    def run_w2v(sentence_id,word_id,emb_size=128):
        res_dict= w2v_pro(datalog,sentence_id=sentence_id,word_id=word_id,
                          emb_size=emb_size,dropna=False,n_jobs=-1, 
                          method='cbow', hs=0,negative=10,epoch=10,
                          return_model=False)
        Cache.cache_data(res_dict,nm_marker=f'EMB_DICT_W2V_CBOW_10EPOCH_{sentence_id}_{word_id}')

    sentence_id='user_id'
    for word_id in tqdm(['creative_id', 'ad_id', 'product_id', 'advertiser_id']):
        run_w2v(sentence_id,word_id,emb_size=128)

    run_w2v(sentence_id,word_id='product_category',emb_size=8)
    run_w2v(sentence_id,word_id='industry',emb_size=64)
    ----------
    """
    if method.lower() in ['sg', 'skipgram']:
        sg = 1
    elif method.lower() in ['cbow']:
        sg = 0
    else:
        raise NotImplementedError
    list_col_nm = f'{sentence_id}__{word_id}_list'
    if (n_jobs is None) or (n_jobs <= 0):
        n_jobs = multiprocessing.cpu_count()
    print(f"========== W2V:  {sentence_id} {word_id} ==========")

    df = df_raw[[sentence_id, word_id, 'pt_d']].copy()

    if df[sentence_id].isnull().sum() > 0:
        print("NaNs exist in sentence_id column!!")
    if dropna:
        df = df.dropna(subset=[sentence_id, word_id])
    else:
        df[word_id] = df[word_id].fillna(-1).astype(int).astype(str)
        df[sentence_id] = df[sentence_id].fillna(-1).astype(int).astype(str)

    df['pt_d_last'] = df['pt_d'] + slide_window
    fe = df.groupby([sentence_id, 'pt_d_last'])[word_id].apply(lambda x: list(x)).reset_index()
    fe.columns = [sentence_id, 'pt_d', list_col_nm]
    df = df.merge(fe, on=[sentence_id, 'pt_d'], how='left')
    df[list_col_nm] = df[list_col_nm].map(lambda x: x if isinstance(x, list) else [])
    # 加上本行的
    df[word_id + '_add'] = df[word_id].map(lambda x: [x])
    df[list_col_nm] = df[list_col_nm] + df[word_id + '_add']
    sentences = df[list_col_nm].values.tolist()
    all_words_vocabulary = df[word_id].unique().tolist()
    del df[list_col_nm], df['pt_d_last'], df[word_id + '_add']
    gc.collect()
    if embedding_type == 'w2v':
        model = Word2Vec(
            sentences,
            size=emb_size,
            window=window,
            workers=n_jobs,
            min_count=1,  # 最低词频. min_count>1会出现OOV
            sg=sg,  # 1 for skip-gram; otherwise CBOW.
            hs=hs,  # If 1, hierarchical softmax will be used for model training
            negative=negative,  # hs=1 + negative 负采样
            iter=epoch,
            seed=0)
    else:
        model = models.FastText(sentences, size=emb_size,
                                window=window, workers=n_jobs, seed=0, sg=sg, iter=epoch)

    # get word embedding matrix
    emb_dict = {}
    for word_i in all_words_vocabulary:
        if word_i in model.wv:
            emb_dict[word_i] = model.wv[word_i]
        else:
            emb_dict[word_i] = np.zeros(emb_size)

    # get sentence embedding matrix
    emb_matrix = []
    for seq in sentences:
        vec = []
        for w in seq:
            if w in model.wv:
                vec.append(model.wv[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * emb_size)
    emb_matrix = np.array(emb_matrix)
    emb_cols = []
    for i in range(emb_size):
        df[f'EMB_{embedding_type}_{sentence_id}_{word_id}_{slide_window}_emb_{i}'] = emb_matrix[:, i]
        emb_cols.append(f'EMB_{embedding_type}_{sentence_id}_{word_id}_{slide_window}_emb_{i}')

    if not return_model:
        model = None
    return {"word_emb_dict": emb_dict, "sentence_emb_df": df[emb_cols], 'model': model}


if __name__ == "__main__":
    # base feature
    df = Cache.reload_cache('CACHE_data_0912.pkl')
    df['communication_onlinerate'] = df['communication_onlinerate'].map(lambda x:x.split(' '))
    df['communication_onlinerate'] = df['communication_onlinerate'].map(lambda x:x if isinstance(x,list) else [])
    n_jobs = 50
    sparse_features=['creat_type_cd', 'slot_id', 
                     'tags', 'app_first_class', 'app_second_class', 'city', 'device_name', 'career',
                     'gender', 'net_type', 'residence', 'emui_dev', 'indu_name', 'age', 'label']
    '''
    ['task_id', 'adv_id', 'creat_type_cd', 'adv_prim_id', 'dev_id', 'inter_type_cd', 'slot_id', 
                     'spread_app_id', 'tags', 'app_first_class', 'app_second_class', 'city', 'device_name', 'career',
                     'gender', 'net_type', 'residence', 'emui_dev', 'indu_name', 'age', 'city_rank','label']
    '''
    dense_features=['his_app_size', 'his_on_shelf_time', 'app_score', 'device_size', 'list_time', 'device_price', 
                    'communication_avgonline_30d', 'cmr_None','sample_nunique']
    df = df[['index','uid','pt_d','communication_onlinerate']+sparse_features+dense_features]
    gc.collect()
#     # 造一份代码
#     df = pd.DataFrame(np.random.randint(0, 21, (5000, 5)), columns=['uid', 'pt_d', 'task_id', 'adv_id', 'values'])
#     df['task_id'] = df['task_id']
#     df['adv_id'] = df['adv_id']
#     df['pt_d'] = df['pt_d'] // 5
#     df = df.sort_values(['uid', 'pt_d', 'task_id', 'adv_id']).reset_index(drop=True)
#     df['label'] = np.random.randint(0, 2, (5000, 1))
#     df = df.reset_index()
#     df['communication_onlinerate'] = [' '.join(str(j) for j in np.random.randint(0, 25, (20,))) for i in
#                                       range(df.shape[0])]
    # 直接做embedding
    sentences = df['communication_onlinerate'].values.tolist()
    model = Word2Vec(
        sentences,
        size=8,
        window=5,
        workers=4,
        min_count=1,  # 最低词频. min_count>1会出现OOV
        sg=0,  # 1 for skip-gram; otherwise CBOW.
        hs=0,  # If 1, hierarchical softmax will be used for model training
        negative=5,  # hs=1 + negative 负采样
        iter=5,
        seed=0)
    # get sentence embedding matrix
    emb_matrix = []
    for seq in sentences:
        vec = []
        for w in seq:
            if w in model.wv:
                vec.append(model.wv[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * 8)
    emb_matrix = np.array(emb_matrix)
    add_cols = []
    for i in range(8):
        df[f'EMB_w2v_uid_communication_onlinerate_0_emb_{i}'] = emb_matrix[:, i]
        add_cols.append(f'EMB_w2v_uid_communication_onlinerate_0_emb_{i}')
    Cache.cache_data(df[['index']+add_cols],nm_marker=f'EMB_DICT_8_1_8_uid_communication_onlinerate_w2v')
    del df['communication_onlinerate'],model,emb_matrix,sentences
    df = df.drop(add_cols,axis=1)
    gc.collect()
    
    # 过去一天的序列，做embedding
    df = reduce_mem(df, use_float16=True)
    gc.collect()

    # w2v
    def run_w2v(df, sentence_id, word_id, emb_size=256, window=10, slid_window=1, embedding_type='w2v', n_jobs = 72):
        res_dict = get_embedding_pro(df, sentence_id=sentence_id, word_id=word_id, window=window,
                                     slide_window=slid_window,
                                     emb_size=emb_size, dropna=False, n_jobs=n_jobs, return_model=False, epoch=5,
                                     embedding_type=embedding_type)
    
        return res_dict["sentence_emb_df"]
    
    emb_size_dict = {}
    for var in tqdm(sparse_features+dense_features):
        nunique_nums = df[var].nunique()
        emb_dim = max([nunique_nums//50,8])
        emb_dim = 32 if emb_dim>16 else (16 if emb_dim>8 else 8)
        emb_size_dict[var] = emb_dim
        print(var,' emb_dim: ',emb_dim)
        fe = run_w2v(df, 'uid', var, emb_size=emb_dim, window=8,slid_window=1, embedding_type='w2v', n_jobs = n_jobs)
        fe['index'] = df['index']
        Cache.cache_data(fe,nm_marker=f'EMB_DICT_8_1{emb_dim}_uid_{var}_w2v')
#         fe = run_w2v(df, 'uid', var, emb_size=emb_dim, window=8,slid_window=1, embedding_type='w2v', n_jobs = n_jobs)
#         fe = reduce_mem(fe, use_float16=True)
#         df = pd.concat([df, fe], axis=1)
#         fe = run_w2v(df, 'uid', var, emb_size=emb_dim, window=8,slid_window=1, embedding_type='fasttext', n_jobs = n_jobs)
#         fe = reduce_mem(fe, use_float16=True)
#         df = pd.concat([df, fe], axis=1)
        
#         fe = run_w2v(df, 'uid', var, emb_size=emb_dim, window=16,slid_window=2, embedding_type='w2v', n_jobs = n_jobs)
#         fe = reduce_mem(fe, use_float16=True)
#         df = pd.concat([df, fe], axis=1)
#         fe = run_w2v(df, 'uid', var, emb_size=emb_dim, window=16,slid_window=2, embedding_type='fasttext', n_jobs = n_jobs)
#         fe = reduce_mem(fe, use_float16=True)
#         del df[var]
#         gc.collect()
#         df = pd.concat([df, fe], axis=1)
        
#     cols_to_save = [i for i in df.columns if i.find('EMB_') > -1]
#     df = df[['index'] + cols_to_save]
#     Cache.cache_data(df, nm_marker='EMB_feature0912')
