# %%
import pandas as pd
import numpy as np
import gc
from base import Cache
from tqdm import tqdm
from gensim.models import Word2Vec
import sys
from multiprocessing import Pool
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('precision', 5)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('max_colwidth', 200)
pd.set_option('display.width', 5000)

def reduce_mem(df, use_float16=False):
    start_mem = df.memory_usage().sum() / 1024**2
    tm_cols = df.select_dtypes('datetime').columns
    for col in df.columns:
        if col in tm_cols:
            continue
        col_type = df[col].dtypes
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(
                        np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(
                        np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(
                        np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(
                        np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if use_float16 and c_min > np.finfo(
                        np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(
                        np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    print('{:.2f} Mb, {:.2f} Mb ({:.2f} %)'.format(
        start_mem, end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df
    
def gen_list_df(data,item_fe_list):
    setitem_fe_list = data.groupby(item_fe_list)['raw_index'].count().reset_index()# 所有feature1
    del setitem_fe_list['raw_index']
    setkey = set(data['user_f'].astype(str))
    ## 所有点击行为的
    list_df=data.query('label==1').groupby(item_fe_list)['user_f'].apply(lambda x: list(x)).\
            rename('list_user_f').reset_index()
    list_df = setitem_fe_list.merge(list_df,on=item_fe_list,how='left')
    list_df['list_user_f']=list_df['list_user_f'].map(lambda x:x if isinstance(x,list) else ['N'])
    list_df_list = list_df['list_user_f'].values.tolist()
    print('w2v start!')
    model = Word2Vec(
    list_df_list,
    size=128,
    window=10000,# 增加了10倍
    workers=10,
    min_count=1,
    sg=0,
    hs=0,
    negative=5,
    iter=10,
    seed=0)
    emb_matrix = []
    for seq in list_df_list:# 对应每个'item_f'
        vec = []
        for w in seq:
            vec.append(model.wv[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * 128)
            
    emb_matrix = np.array(emb_matrix,dtype=np.float32)
    dict_feature1 = {}
    for index,key in enumerate(list(list_df[item_fe_list])):
        dict_feature1[key]=emb_matrix[index,:]# feature1的字典 key是item_f
    # 直接存emb
    # index,emb_item,emb_user
    np.save('./cached_data/dataindex_stage2.npy',data['raw_index'].values)
    m1_item = []
    for i in tqdm(list(data[item_fe_list])):
        m1_item.append(dict_feature1[i])
    m1_item = np.array(m1_item,dtype=np.float32)
    m1_user = []
    for i in tqdm(list(data['user_f'])):
        try:
            m1_user.append(model.wv[i])
        except:
            m1_user.append([0] * 128)
    m1_user = np.array(m1_user,dtype=np.float32)
    print(m1_item.shape)
    np.save('./cached_data/m1_item_stage2.npy',m1_item)
    print(m1_user.shape)
    np.save('./cached_data/m1_user_stage2.npy',m1_user)
    ## 所有无点击行为的
    list_df=data.query('label==0').groupby(item_fe_list)['user_f'].apply(lambda x: list(x)).\
            rename('list_user_f').reset_index()
    list_df = setitem_fe_list.merge(list_df,on=item_fe_list,how='left')
    list_df['list_user_f']=list_df['list_user_f'].map(lambda x:x if isinstance(x,list) else ['N'])
    list_df_list = list_df['list_user_f'].values.tolist()
    print('w2v start!')
    model = Word2Vec(
    list_df_list,
    size=128,
    window=10000,# 增加了10倍
    workers=10,
    min_count=1,
    sg=0,
    hs=0,
    negative=5,
    iter=10,
    seed=0)
    emb_matrix = []
    for seq in list_df_list:# 对应每个'item_f'
        vec = []
        for w in seq:
            vec.append(model.wv[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * 64)
            
    emb_matrix = np.array(emb_matrix,dtype=np.float32)
    dict_feature1 = {}
    for index,key in enumerate(list(list_df[item_fe_list])):
        dict_feature1[key]=emb_matrix[index,:]# feature1的字典 key是item_f
    # 直接存emb
    m1_item = []
    for i in tqdm(list(data[item_fe_list])):
        m1_item.append(dict_feature1[i])
    m1_item = np.array(m1_item,dtype=np.float32)
    m1_user = []
    for i in tqdm(list(data['user_f'])):
        try:
            m1_user.append(model.wv[i])
        except:
            m1_user.append([0] * 128)
    m1_user = np.array(m1_user,dtype=np.float32)
    print(m1_item.shape)
    np.save('./cached_data/m0_item_stage2.npy',m1_item)
    print(m1_user.shape)
    np.save('./cached_data/m0_user_stage2.npy',m1_user)
    

from multiprocessing import Pool
if __name__ == '__main__':
    print('start!')
    data = Cache.reload_cache('CACHE_sampling_pro_feature.pkl')
    print(data.shape)
    data['label']=data['label'].fillna(2).astype(int)# mask
    gc.collect()
    print('w2v start!')
    # 生成一个emb matrix
    user_fe_list = ['age','city_rank','gender','slot_id','net_type']# 'city_rank'
    item_fe_list = ['task_id','adv_id','creat_type_cd','dev_id','inter_type_cd','indu_name', 'adv_prim_id','tags','spread_app_id',
                    'app_first_class','his_on_shelf_time']
    print('join!')# 简化的预训练方式 将用户属性，广告属性做拼接，大窗口做预训练学习共现分布
    data['user_f'] = ''
    for i,vari in enumerate(user_fe_list):
        data['user_f'] = data['user_f']+_+data[vari].astype('str')
    data['item_f'] = ''
    for i,vari in enumerate(item_fe_list):
        data['item_f'] = data['item_f']+_+data[vari].astype('str')
    gen_list_df(data,'item_f')
# Out:
# start!
# [2020-09-28 00:57:34] - __init__.py[line:127] - INFO: Successfully Reload: /home/tione/notebook/huawei/cached_data/CACHE_sampling_pro_feature.pkl
# (9672928, 297)
# [2020-09-28 00:57:34] - utils.py[line:129] - INFO: Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2020-09-28 00:57:34] - utils.py[line:141] - INFO: NumExpr defaulting to 8 threads.
# w2v start!
# join!
# [2020-09-28 00:58:44] - word2vec.py[line:1399] - INFO: collecting all words and their counts
# [2020-09-28 00:58:44] - word2vec.py[line:1384] - INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# w2v start!
# [2020-09-28 00:58:45] - word2vec.py[line:1407] - INFO: collected 1986 word types from a corpus of 1447409 raw words and 6589 sentences
# [2020-09-28 00:58:45] - word2vec.py[line:1458] - INFO: Loading a fresh vocabulary
# [2020-09-28 00:58:45] - word2vec.py[line:1482] - INFO: effective_min_count=1 retains 1986 unique words (100% of original 1986, drops 0)
# [2020-09-28 00:58:45] - word2vec.py[line:1488] - INFO: effective_min_count=1 leaves 1447409 word corpus (100% of original 1447409, drops 0)
# [2020-09-28 00:58:45] - word2vec.py[line:1547] - INFO: deleting the raw counts dictionary of 1986 items
# [2020-09-28 00:58:45] - word2vec.py[line:1550] - INFO: sample=0.001 downsamples 92 most-common words
# [2020-09-28 00:58:45] - word2vec.py[line:1553] - INFO: downsampling leaves estimated 1007272 word corpus (69.6% of prior 1447409)
# [2020-09-28 00:58:45] - base_any2vec.py[line:1008] - INFO: estimated required memory for 1986 words and 128 dimensions: 3026664 bytes
# [2020-09-28 00:58:45] - word2vec.py[line:1699] - INFO: resetting layer weights
# [2020-09-28 00:58:45] - base_any2vec.py[line:1196] - INFO: training model with 10 workers on 1986 vocabulary and 128 features, using sg=0 hs=0 sample=0.001 negative=5 window=10000
# [2020-09-28 00:58:47] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 0.09% examples, 2264 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:48] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 7.51% examples, 12389 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:49] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 11.82% examples, 15504 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:50] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 13.81% examples, 15031 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:51] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 18.09% examples, 14936 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:55] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 20.35% examples, 11388 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:57] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 22.10% examples, 10439 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:58] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 22.54% examples, 10791 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:58:59] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 24.97% examples, 10245 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:01] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 25.89% examples, 10018 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:02] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 28.34% examples, 10765 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:04] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 29.23% examples, 10579 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:05] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 33.02% examples, 10490 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:07] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 34.25% examples, 10572 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:09] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 36.18% examples, 10197 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:11] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 37.11% examples, 9655 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:12] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 38.14% examples, 9957 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:15] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 40.39% examples, 9689 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:17] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 42.36% examples, 9324 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:18] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 44.91% examples, 9454 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:20] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 45.29% examples, 9721 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 00:59:21] - base_any2vec.py[line:1291] - INFO: EPOCH 1 - PROGRESS: at 48.55% examples, 9904 words/s, in_qsize 19, out_qsize 0
# [2020-09-28
- base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 0 more threads
# [2020-09-28 01:02:19] - base_any2vec.py[line:1332] - INFO: EPOCH - 2 : training on 1447409 raw words (946409 effective words) took 106.8s, 8863 effective words/s
# [2020-09-28 01:02:21] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 0.09% examples, 2374 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:22] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 8.45% examples, 11945 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:23] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 12.75% examples, 15855 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:25] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 15.92% examples, 15237 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:26] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 19.15% examples, 15057 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:28] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 20.35% examples, 11914 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:30] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 22.10% examples, 10924 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:31] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 22.29% examples, 10733 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:33] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 24.97% examples, 10528 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:35] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 25.89% examples, 10225 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:36] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 28.34% examples, 10963 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:38] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 29.38% examples, 10761 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:39] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 33.02% examples, 10733 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:41] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 34.25% examples, 10606 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:42] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 36.18% examples, 10348 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:44] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 37.11% examples, 10266 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:46] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 37.78% examples, 9817 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:47] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 40.37% examples, 9968 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:49] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 40.39% examples, 9669 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:51] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 41.14% examples, 9352 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:52] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 44.60% examples, 9648 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:54] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 45.27% examples, 9529 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:55] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 47.75% examples, 9704 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:56] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 48.55% examples, 9781 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:02:58] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 50.30% examples, 9664 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:00] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 51.59% examples, 9614 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:01] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 52.30% examples, 9742 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:02] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 54.73% examples, 9752 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:03] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 55.53% examples, 9611 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:05] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 57.11% examples, 9685 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:06] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 61.19% examples, 9816 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:08] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 62.07% examples, 9707 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:10] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 63.50% examples, 9440 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:12] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 67.75% examples, 9608 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:13] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 73.23% examples, 9821 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:14] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 76.40% examples, 9895 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:15] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 79.59% examples, 9893 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:17] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 79.92% examples, 9874 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:18] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 80.21% examples, 9710 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:19] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 84.08% examples, 9917 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:20] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 84.17% examples, 9807 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:22] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 85.76% examples, 9783 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:24] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 85.78% examples, 9592 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:26] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 87.77% examples, 9590 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:28] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 90.68% examples, 9620 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:31] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 93.19% examples, 9583 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:32] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 94.92% examples, 9876 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:33] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 96.19% examples, 9882 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:35] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 97.25% examples, 9964 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:39] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 97.33% examples, 9557 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:42] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 97.34% examples, 9377 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:43] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 97.36% examples, 9313 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:46] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 97.44% examples, 9196 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:03:49] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 98.07% examples, 9059 words/s, in_qsize 17, out_qsize 0
# [2020-09-28 01:03:51] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 98.83% examples, 9186 words/s, in_qsize 13, out_qsize 0
# [2020-09-28 01:03:53] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.12% examples, 9060 words/s, in_qsize 12, out_qsize 0
# [2020-09-28 01:03:56] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.27% examples, 8879 words/s, in_qsize 10, out_qsize 0
# [2020-09-28 01:03:57] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.59% examples, 8810 words/s, in_qsize 9, out_qsize 1
# [2020-09-28 01:03:57] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 9 more threads
# [2020-09-28 01:03:58] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 8 more threads
# [2020-09-28 01:03:58] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.89% examples, 8844 words/s, in_qsize 7, out_qsize 1
# [2020-09-28 01:03:58] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 7 more threads
# [2020-09-28 01:04:00] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.91% examples, 8834 words/s, in_qsize 6, out_qsize 1
# [2020-09-28 01:04:00] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 6 more threads
# [2020-09-28 01:04:00] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 5 more threads
# [2020-09-28 01:04:00] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 4 more threads
# [2020-09-28 01:04:01] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.95% examples, 8998 words/s, in_qsize 3, out_qsize 1
# [2020-09-28 01:04:01] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 3 more threads
# [2020-09-28 01:04:04] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.97% examples, 8811 words/s, in_qsize 2, out_qsize 1
# [2020-09-28 01:04:04] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 2 more threads
# [2020-09-28 01:04:06] - base_any2vec.py[line:1291] - INFO: EPOCH 3 - PROGRESS: at 99.98% examples, 8758 words/s, in_qsize 1, out_qsize 1
# [2020-09-28 01:04:06] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 1 more threads
# [2020-09-28 01:04:06] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 0 more threads
# [2020-09-28 01:04:06] - base_any2vec.py[line:1332] - INFO: EPOCH - 3 : training on 1447409 raw words (947333 effective words) took 107.2s, 8834 effective words/s
# [2020-09-28 01:04:08] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 0.09% examples, 2404 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:09] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 7.51% examples, 13029 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:10] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 11.82% examples, 15755 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:11] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 15.91% examples, 16873 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:12] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 18.09% examples, 15322 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:16] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 20.35% examples, 11475 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:18] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 22.10% examples, 10558 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:19] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 22.54% examples, 10624 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:20] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 25.21% examples, 10834 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:22] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 25.89% examples, 10372 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:23] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 27.39% examples, 10823 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:25] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 29.38% examples, 10834 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:26] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 33.02% examples, 10670 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:28] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 34.25% examples, 10715 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:29] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 36.18% examples, 10392 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:32] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 37.11% examples, 9773 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:33] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 38.14% examples, 9987 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:36] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 40.39% examples, 9712 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:38] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 41.14% examples, 9411 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:39] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 44.91% examples, 9604 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:41] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 45.27% examples, 9636 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:42] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 47.75% examples, 9720 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:44] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 49.29% examples, 9805 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:45] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 50.30% examples, 9701 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:46] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 51.59% examples, 9809 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:47] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 52.13% examples, 9620 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:48] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 53.89% examples, 9849 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:49] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 54.73% examples, 9758 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:52] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 57.10% examples, 9485 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:54] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 60.90% examples, 9569 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:55] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 62.07% examples, 9664 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:57] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 63.20% examples, 9594 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:04:58] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 63.83% examples, 9430 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:00] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 73.23% examples, 9881 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:01] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 76.40% examples, 9963 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:02] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 76.96% examples, 9880 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:04] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 79.92% examples, 9885 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:05] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 80.80% examples, 9693 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:06] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 84.08% examples, 9944 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:07] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 84.78% examples, 9924 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:11] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 85.76% examples, 9653 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:12] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 85.78% examples, 9611 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:13] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 86.30% examples, 9623 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:16] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 90.68% examples, 9551 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:18] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 92.79% examples, 9623 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:19] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 94.55% examples, 9875 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:20] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 96.19% examples, 9903 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:22] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 97.06% examples, 9910 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:26] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 97.33% examples, 9603 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:29] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 97.34% examples, 9419 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:30] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 97.36% examples, 9355 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:33] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 97.44% examples, 9265 words/s, in_qsize 19, out_qsize 0
# [2020-09-28 01:05:35] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 98.07% examples, 9132 words/s, in_qsize 17, out_qsize 0
# [2020-09-28 01:05:37] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 98.65% examples, 9133 words/s, in_qsize 15, out_qsize 0
# [2020-09-28 01:05:39] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.12% examples, 9095 words/s, in_qsize 12, out_qsize 0
# [2020-09-28 01:05:43] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.27% examples, 8922 words/s, in_qsize 10, out_qsize 0
# [2020-09-28 01:05:44] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.59% examples, 8855 words/s, in_qsize 9, out_qsize 1
# [2020-09-28 01:05:44] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 9 more threads
# [2020-09-28 01:05:44] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 8 more threads
# [2020-09-28 01:05:45] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 7 more threads
# [2020-09-28 01:05:46] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.91% examples, 8876 words/s, in_qsize 6, out_qsize 1
# [2020-09-28 01:05:46] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 6 more threads
# [2020-09-28 01:05:47] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 5 more threads
# [2020-09-28 01:05:47] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 4 more threads
# [2020-09-28 01:05:48] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.95% examples, 9037 words/s, in_qsize 3, out_qsize 1
# [2020-09-28 01:05:48] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 3 more threads
# [2020-09-28 01:05:51] - base_any2vec.py[line:1291] - INFO: EPOCH 4 - PROGRESS: at 99.97% examples, 8838 words/s, in_qsize 2, out_qsize 1
# [2020-09-28 01:05:51] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of
- base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.47% examples, 6081 words/s, in_qsize 14, out_qsize 0
# [2020-09-28 03:01:17] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.50% examples, 6090 words/s, in_qsize 12, out_qsize 0
# [2020-09-28 03:01:19] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.64% examples, 6090 words/s, in_qsize 10, out_qsize 0
# [2020-09-28 03:01:23] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.85% examples, 6062 words/s, in_qsize 9, out_qsize 1
# [2020-09-28 03:01:23] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 9 more threads
# [2020-09-28 03:01:23] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 8 more threads
# [2020-09-28 03:01:24] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.89% examples, 6072 words/s, in_qsize 7, out_qsize 1
# [2020-09-28 03:01:24] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 7 more threads
# [2020-09-28 03:01:29] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.91% examples, 6043 words/s, in_qsize 6, out_qsize 1
# [2020-09-28 03:01:29] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 6 more threads
# [2020-09-28 03:01:30] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.92% examples, 6046 words/s, in_qsize 5, out_qsize 1
# [2020-09-28 03:01:30] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 5 more threads
# [2020-09-28 03:01:32] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.94% examples, 6047 words/s, in_qsize 4, out_qsize 1
# [2020-09-28 03:01:32] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 4 more threads
# [2020-09-28 03:01:32] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 3 more threads
# [2020-09-28 03:01:33] - base_any2vec.py[line:1291] - INFO: EPOCH 10 - PROGRESS: at 99.97% examples, 6065 words/s, in_qsize 2, out_qsize 1
# [2020-09-28 03:01:33] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 2 more threads
# [2020-09-28 03:01:33] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 1 more threads
# [2020-09-28 03:01:34] - base_any2vec.py[line:348] - INFO: worker thread finished; awaiting finish of 0 more threads
# [2020-09-28 03:01:34] - base_any2vec.py[line:1332] - INFO: EPOCH - 10 : training on 7227850 raw words (3759890 effective words) took 617.4s, 6090 effective words/s
# [2020-09-28 03:01:34] - base_any2vec.py[line:1368] - INFO: training on a 72278500 raw words (37602825 effective words) took 6166.2s, 6098 effective words/s
# 100%|██████████| 9672928/9672928 [00:03<00:00, 2621717.27it/s]
# 100%|██████████| 9672928/9672928 [00:20<00:00, 465757.36it/s]
# (9672928, 128)
# (9672928, 128)

# %%
item_fe_list
# Out:
# ['task_id',
#  'adv_id',
#  'creat_type_cd',
#  'dev_id',
#  'inter_type_cd',
#  'indu_name',
#  'adv_prim_id',
#  'tags',
#  'spread_app_id',
#  'app_first_class',
#  'his_on_shelf_time']

# %% [markdown]
# ## finished!

# %%
import os
dir(os.path)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_get_sep',
#  '_joinrealpath',
#  '_varprog',
#  '_varprogb',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdir',
#  'isfile',
#  'islink',
#  'ismount',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
#  'sameopenfile',
#  'samestat',
#  'sep',
#  'split',
#  'splitdrive',
#  'splitext',
#  'stat',
#  'supports_unicode_filenames',
#  'sys']

# %%
os.path.exists('./cached_data/m1_item_stage2.npy')
# Out:
# False
